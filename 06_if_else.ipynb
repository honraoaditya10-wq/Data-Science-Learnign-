# %%
a = 12

# %%
if(a>23):
    print("a os greater than 23")
else:
    print("a is less than 23")
# Out:
# a is less than 23

# %%
no = -2

# %%
if (no > 20):
    print("greater")
elif(no < 20 and no > 0 ):
    print("Smaller")
elif(no < 0 ):
    print("negative")
else:
    print("invalid")
# Out:
# negative
