# %%
name = "Aditya"
age = 18

# %%
print("Hello! My name is {} and I am {} old".format(name,age)) #old Method
# Out:
# Hello! My name is Aditya and I am 18 old

# %%
print(f"Hello ! My Name is {name} and I am {age} years old") #New Method
# Out:
# Hello ! My Name is Aditya and I am 18 years old

# %%
print(f"{'python':<123}")
print(f"{'python':>16}")
print(f"{'python':^123}")
# Out:
# python
#           python
#                                                           python
