# %%
a = 5

# %%
b = 32

# %%
a + b
# Out:
# 37

# %%
name = "Aditya"

# %%
print("Hello World") # this will print hello world on the screen
# Out:
# Hello World

# %%
# this is the comment

# %% [raw]
# print(type(a))

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
boolean = True

# %%
print(type(boolean))
# Out:
# <class 'bool'>

# %%
type(name)
# Out:
# str

# %%
type(a)
# Out:
# int

# %%
a = 123

# %%
b = 456

# %%
a + b
# Out:
# 579

# %%
str(a) + str(b) # type casting in the python
# Out:
# '123456'
