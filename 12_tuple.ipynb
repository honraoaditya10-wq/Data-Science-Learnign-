# %%
# Tuple in python is order whihc is imutable , we can not chnage it

# %%
empty_tuple = ()

# %%
type(empty_tuple)
# Out:
# tuple

# %%
e = (1,2,3,4,5)

# %%
e
# Out:
# (1, 2, 3, 4, 5)

# %%
len(e)
# Out:
# 5

# %%
e[0]
# Out:
# 1

# %%
print(e[2])
# Out:
# 3

# %%
person = ("Aditya",18,"diploma")

# %%
name,age, profession = person

# %%
person
# Out:
# ('Aditya', 18, 'diploma')

# %%
name
# Out:
# 'Aditya'

# %%
age
# Out:
# 18

# %%
profession
# Out:
# 'diploma'

# %%
person.count(18)
# Out:
# 1
