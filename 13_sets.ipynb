# %%
# A set in Python is an unordered, mutable, and unique collection of elements. It
# does not allow duplicate values

# %%
my_dict = {}

# %%
type(my_dict)
# Out:
# dict

# %%
s = {1,2,3,4,5}

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s1 = {1,1,2,2,4,5}

# %%
s1
# Out:
# {1, 2, 4, 5}

# %%
mixed_set = {"Aditya" ,23,34 }

# %%
mixed_set
# Out:
# {23, 34, 'Aditya'}

# %%
s = {1,1,2,2,4,5}

# %%
s.add(30)

# %%
s
# Out:
# {1, 2, 4, 5, 30}

# %%
s.update([2,34,5,21,23])

# %%
s
# Out:
# {1, 2, 4, 5, 21, 23, 30, 34}

# %%
s.remove(1)

# %%
s
# Out:
# {2, 4, 5, 21, 23, 30, 34}

# %%
s.discard(44)

# %%
s
# Out:
# {2, 5, 21, 23, 30, 34}

# %%
s.pop()
# Out:
# 34

# %%
s
# Out:
# {5, 21, 23, 30}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
set1 = {1,2,3,4,5}

# %%
set2 = {6,7,8,9,1,2,3}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
set1
# Out:
# {1, 2, 3, 4, 5}

# %%
set2
# Out:
# {1, 2, 3, 6, 7, 8, 9}

# %%
set1.intersection(set2)
# Out:
# {1, 2, 3}

# %%
 sub = {1,2}

# %%
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True
