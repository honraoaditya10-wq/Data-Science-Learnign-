# %%
a = int(input("Enter The value of 'A' "))  # by default it takes user input as the 'String'
# Out:
# Enter The value of 'A'  12

# %%
a
# Out:
# 12

# %%
b = int(input("Enter The value of 'B' "))
# Out:
# Enter The value of 'B'  12

# %%
a + b
# Out:
# 24

# %%
int(a)  + int(b)
# Out:
# 24

# %%
c = input()
# Out:
#  23

# %%
c
# Out:
# '23'

# %%
a + int(c)
# Out:
# 35
