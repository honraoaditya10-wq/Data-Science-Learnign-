# %%
f = open("aditya.txt","r")

# %%
f.read()
# Out:
# 'Hello Python!\nhi Aditya.\nHow are you ? '

# %%
f.close()

# %%
f = open("aditya.txt", "w")

# %%
add = " \n This text is Added!"

# %%
f.write(add)
# Out:
# 22

# %%
import os  
n  = os.path.exists("aditya.txt")

# %%
n
# Out:
# True
