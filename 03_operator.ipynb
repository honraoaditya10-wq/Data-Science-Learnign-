# %% [markdown]
# Arithamatic Operator

# %%
a = 10

# %%
b = 15

# %%
a+b
# Out:
# 25

# %%
a-b
# Out:
# -5

# %%
a*b
# Out:
# 150

# %%
a/b
# Out:
# 0.6666666666666666

# %%
a//b
# Out:
# 0

# %%
2**3
# Out:
# 8

# %%
2**5
# Out:
# 32

# %%
a**b
# Out:
# 1000000000000000

# %%
a%b
# Out:
# 10

# %% [markdown]
# Comparasion Operator

# %%
x = 11

# %%
y  = 30

# %% [markdown]
# x >= y

# %%
x <= y
# Out:
# True

# %%
z = 45

# %%
x == z #is x equl to z
# Out:
# False

# %%
x !=z
# Out:
# True

# %% [markdown]
# Logical Operator

# %%
b1 = True
b2 = True

# %%
b1 and b2
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %% [markdown]
# BitWise Operator
