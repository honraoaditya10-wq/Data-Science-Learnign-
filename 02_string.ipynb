# %%
name = "Aditay" #String is the collection of character in python

# %%
name
# Out:
# 'Aditay'

# %%
name.upper()
# Out:
# 'ADITAY'

# %%
name.endswith(" Honrao")
# Out:
# False

# %%
name.endswith("tay")
# Out:
# True

# %%
name.lower()
# Out:
# 'aditay'

# %%
name.count("a")
# Out:
# 1

# %%
name.count("e")
# Out:
# 0

# %%
len(name)
# Out:
# 6

# %%
name.replace("Aditya","Honrao")
# Out:
# 'Aditay'

# %%
name
# Out:
# 'Aditay'

# %%
name.replace("Aditya","Honrao")
# Out:
# 'Aditay'

# %%
name.replace("Honrao", "Aditya")
# Out:
# 'Aditay'

# %%
name
# Out:
# 'Aditay'

# %%
name[1:5]
# Out:
# 'dita'

# %%
name[0:6]
# Out:
# 'Aditay'

# %%
name[-1:-6]
# Out:
# ''

# %%
name[-1:6]
# Out:
# 'y'

# %%
name[]
