# %%
result = 10 + 2 * 4

# %%
result
# Out:
# 18

# %%
result1 = (10 + 2 ) * 4

# %%
result1
# Out:
# 48

# %%
2 ** 3 ** 2
# Out:
# 512

# %%
# Sequence

# %% [markdown]
#  Exponentiation (**) work first righ to left

# %% [markdown]
# Multiplication

# %% [markdown]
# Division

# %% [markdown]
# flor Division (//)

# %% [markdown]
# Modul (%)

# %% [markdown]
# Addition

# %% [markdown]
# Substraction
