# %%
def avg(a,b):
    return (a+b)/2

# %%
avg(10,11)
# Out:
# 10.5

# %%
def mul(a,b):
    return a*b

# %%
mul(2,2)
# Out:
# 4

# %%
def greet():
    print("hello Good Evening")

# %%
greet()
# Out:
# hello Good Evening
