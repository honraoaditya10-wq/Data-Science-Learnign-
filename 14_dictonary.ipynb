# %%
# Dictionary with key-value pairs
student = {
"name": "Alice",
"age": 25,
"grade": "A"
}

# %%
student
# Out:
# {'name': 'Alice', 'age': 25, 'grade': 'A'}

# %%
student["name"]
# Out:
# 'Alice'

# %%
r = student.get("namen")

# %%
print(student["age"])
# Out:
# 25

# %%
student["age"] = 34

# %%
print(student["age"])
# Out:
# 34

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Alice', 34, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 34), ('grade', 'A')])

# %%
student.update({"name" : "Aditya"})

# %%
student
# Out:
# {'name': 'Aditya', 'age': 34, 'grade': 'A'}

# %%
student["name"] = "raj"

# %%
student
# Out:
# {'name': 'raj', 'age': 34, 'grade': 'A'}

# %%
student.update({"name" : "Aditya" , "language" : "Python"})

# %%
student
# Out:
# {'name': 'Aditya', 'age': 34, 'grade': 'A', 'language': 'Python'}

# %%
student.values()
# Out:
# dict_values(['Aditya', 34, 'A', 'Python'])

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade', 'language'])

# %%
student.pop("name")
# Out:
# 'Aditya'

# %%
student
# Out:
# {'age': 34, 'grade': 'A', 'language': 'Python'}

# %%
student.setdefault("age","unknown")
# Out:
# 34

# %%
student
# Out:
# {'age': 34, 'grade': 'A', 'language': 'Python', 'city': 'unknown'}

# %%
student.clear()

# %%
student
# Out:
# {}
