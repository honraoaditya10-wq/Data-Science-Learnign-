# %%
l = [1,2,3,4,5]

# %%
l[0] = 11

# %%
l
# Out:
# [11, 2, 3, 4, 5]

# %%
l.append(45)#append

# %%
l
# Out:
# [11, 2, 3, 4, 5, 45]

# %%
l2 = [6,7,8]

# %%
l.extend(l2)#extend

# %%
l
# Out:
# [11, 2, 3, 4, 5, 45, 6, 7, 8]

# %%
l2
# Out:
# [6, 7, 8]

# %%
l
# Out:
# [11, 2, 3, 4, 5, 45, 6, 7, 8]

# %%
l.insert(1,200) #insert

# %%
l
# Out:
# [11, 200, 2, 3, 4, 5, 45, 6, 7, 8]

# %%
l[2] = 300

# %%
l
# Out:
# [11, 200, 300, 3, 4, 5, 45, 6, 7, 8]

# %%
number = l.pop(4)

# %%
number
# Out:
# 4

# %%
l
# Out:
# [11, 200, 300, 3, 5, 45, 6, 7, 8]

# %%
l.index(300)
# Out:
# 2

# %%
l.append(200)

# %%
l.count(200)
# Out:
# 2

# %%
sorted(l)#return a new list that is sorted
# Out:
# [3, 5, 6, 7, 8, 11, 45, 200, 200, 300]

# %%
l
# Out:
# [11, 200, 300, 3, 5, 45, 6, 7, 8, 200]

# %%
l.sort() #return a real list

# %%
l
# Out:
# [3, 5, 6, 7, 8, 11, 45, 200, 200, 300]

# %%
y = [1,2,"Aditya",True,[23,24]] #nested List

# %%
y
# Out:
# [1, 2, 'Aditya', True, [23, 24]]

# %%
y[4]
# Out:
# [23, 24]

# %%
list1 = [1,2,3]

# %%
list2 = [4,5,6]

# %%
list1 + list2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list2 + list1
# Out:
# [4, 5, 6, 1, 2, 3]

# %%
list1
# Out:
# [1, 2, 3]

# %%
3 in list1
# Out:
# True

# %%
33 in list2
# Out:
# False

# %%
name = "Aadi.Raj.Neha.Rahul.Rohit"

# %%
name.split(".")
# Out:
# ['Aadi', 'Raj', 'Neha', 'Rahul', 'Rohit']
