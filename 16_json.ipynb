# %%
import json

# %%
obj = {"name":"Aditya","age":13 , "lang":"python"}

# %%
s = json.dumps(obj)

# %%
s
# Out:
# '{"name": "Aditya", "age": 13, "lang": "python"}'

# %%
d = json.loads('{"name":"Aditya","age":13 , "lang":"python"}')

# %%
type(d)
# Out:
# dict

# %%
type(s)
# Out:
# str

# %%
type(obj)
# Out:
# dict

# %%
detail  = {"name":"Aditya","age":13 , "lang":"python"} 
file  = open("data.json","w")

# %%
json.dump(detail,file)

# %%
file.close()
